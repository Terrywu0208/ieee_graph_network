# %%
import pandas as pd

df = pd.read_csv("../csvdata/social_network_essay_data.csv")

# %%
df[20:]
# Out:
#                                                  title  essayCode  \
# 20   Predicting Links in Social Networks Using Text...    5231915
# 21   A Theoretical Approach for Discovery of Friend...    9381341
# 22   Identifying Structural Heterogeneities between...    5992635
# 23   Social Network measures association with socia...    9377088
# 24   The Analysis on the Role of Social Network in ...    9421847
# ..                                                 ...        ...
# 234  Groupthink and Peer Pressure: Social Influence...    5231938
# 235  A novel socially-aware opportunistic routing a...    6504138
# 236  Traits Measuring Metrics for the Members of Se...    9693017
# 237  A Novel Negative Link Prediction Algorithm for...    9860751
# 238  A user action based approach to determine trus...    8058327
#
#                                              reference  \
# 20   {'Evolution of the social network of scientifi...
# 21   {'Multitask learning for blackmarket tweet det...
# ...
