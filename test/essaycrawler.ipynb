# %%
from bs4 import BeautifulSoup
import requests
import re
import pandas as pd
import json
import time
import random

# %%
def crawl_ieee_paper_authors(essayCode):
    headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'}
    url = f'https://ieeexplore.ieee.org/document/{essayCode}/authors#authors'
    response = requests.get(url, headers=headers)


    if response.status_code == 200:
        soup = BeautifulSoup(response.text, 'html.parser')

        author_tags = soup.find_all('author')

        authors = [author.text.strip() for author in author_tags]

        pattern = re.compile(r'authorNames":"(.*)\"')
        matches = pattern.findall(str(soup))

        if matches:
            authors = [match.strip() for match in matches]
            authors = authors[0].split(",")[0]
            authors = authors.replace('\"',"")
        else:
            print("未找到 authorNames")


    else:
        print(f"Failed to retrieve the page. Status code: {response.status_code}")
    
    return authors

# %%
def crawl_ieee_reference(essayCode):
    headers = {
        'authority': 'ieeexplore.ieee.org',
        'method': 'GET',
        'path': f'/rest/document/{essayCode}/references',
        'scheme': 'https',
        'Accept': 'application/json, text/plain, */*',
        'Accept-Encoding': 'gzip, deflate, br, zstd',
        'Accept-Language': 'zh-TW,zh;q=0.9,en-US;q=0.8,en;q=0.7',
        'Cache-Http-Response': 'true',
        'Referer': f'https://ieeexplore.ieee.org/document/{essayCode}/references',
        'Sec-Ch-Ua': '"Google Chrome";v="119", "Chromium";v="119", "Not?A_Brand";v="24"',
        'Sec-Ch-Ua-Mobile': '?0',
        'Sec-Ch-Ua-Platform': '"Windows"',
        'Sec-Fetch-Dest': 'empty',
        'Sec-Fetch-Mode': 'cors',
        'Sec-Fetch-Site': 'same-origin',
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/119.0.0.0 Safari/537.36',
        'X-Security-Request': 'required'
    }
    url = f'https://ieeexplore.ieee.org/rest/document/{essayCode}/references'

    response = requests.get(url, headers=headers)
    result_dict = {}

    if response.status_code == 200:
        data = response.json()
        for ref in range(len(data["references"])):
            text = data["references"][ref]["text"]
            authors_ls = []

            authors_match = re.search(r'([^,]+),([^"]+)"', text)
            if authors_match:
                authors = authors_match.group(0).strip(' ,').replace('"',"")
                authors_commma = authors.split(",")
                for i in authors_commma:
                    if i :
                        tmp = i.replace("et al.", "")
                        authors_ls.extend(tmp.split("and"))

            title_match = re.search(r'"([^"]+)"', text)
            if title_match:
                title = title_match.group(1)
                authors_ls = [i.strip() for i in authors_ls if i != ' ']
                cleaned_title = re.sub(r'\[[^\]]+\]', '', title)
                result_dict[cleaned_title]=authors_ls
    else:
        print(f"Failed to retrieve the page. Status code: {response.status_code}")
        data = None

    return result_dict

# %%
def getessaylist(queryText, pageNumber):
    url = "https://ieeexplore.ieee.org/rest/search"

    headers = {
        'Accept': 'application/json, text/plain, */*',
        'Accept-Encoding': 'gzip, deflate, br, zstd',
        'Accept-Language': 'zh-TW,zh;q=0.9,en-US;q=0.8,en;q=0.7',
        'Content-Type': 'application/json',
        'Origin': 'https://ieeexplore.ieee.org',
        'Referer': 'https://ieeexplore.ieee.org/search/searchresult.jsp?newsearch=true&queryText=LLM',
        'Sec-Ch-Ua': '"Google Chrome";v="119", "Chromium";v="119", "Not?A_Brand";v="24"',
        'Sec-Ch-Ua-Mobile': '?0',
        'Sec-Ch-Ua-Platform': '"Windows"',
        'Sec-Fetch-Dest': 'empty',
        'Sec-Fetch-Mode': 'cors',
        'Sec-Fetch-Site': 'same-origin',
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/119.0.0.0 Safari/537.36',
        'X-Security-Request': 'required'
    }


    payload = {
        'newsearch': True,
        'queryText': queryText,
        'highlight': True,
        'returnFacets': ['ALL'],
        'returnType': 'SEARCH',
        'pageNumber' : str(pageNumber)
    }

    data = json.dumps(payload, ensure_ascii=False).encode('utf-8')

    response = requests.post(url, headers=headers, data=data)

    response_text = response.content.decode('utf-8')

    response_dict = json.loads(response_text)
    result_dict = {}
    for record in range(len(response_dict["records"])):
        result_dict[response_dict["records"][record]["articleTitle"]] = response_dict["records"][record]["articleNumber"]

    return result_dict

# %%
data_list= []
def main(SearhKeyWord, MaxPage):
    global data_list
    for num in range(1,MaxPage):
        print(f"***********************   Page  {num}   ***********************************")
        essay = getessaylist(SearhKeyWord, num)
        for title, essayCode in essay.items():
            print("-------------------------------------------------------")
            print("essayCode : ", essayCode)
            time.sleep(random.randint(5, 10))
            try:
                references = crawl_ieee_reference(essayCode)
                authors = crawl_ieee_paper_authors(essayCode)
                print("title : ", title)
                print("reference : ", references)
                print("authors : ", authors)
                data_list.append({
                    'title': title,
                    'essayCode': essayCode,
                    'reference': json.dumps(references),
                    'author': authors
                })
            except:
                print("failed")

# %%
main("social network", 11)
df = pd.DataFrame(data_list)
df.to_csv("social_network_essay_data_V2.csv")
# Out:
# ***********************   Page  1   ***********************************
# -------------------------------------------------------
# essayCode :  6921601
# title :  Social networks analysis and perception of social support of young mothers in the process of reconstruction: The social fabric of winter victims in the Colombian Caribbean (South America)
# reference :  {'The Political Network in Mexico: Between Conflict and Stability': ['Schmidt', 'S. y Gil', 'J. (1997)']}
# authors :  Carolina S. Castro;Camilo A. Madariaga
# -------------------------------------------------------
# essayCode :  6113161
# title :  Connecting People in the Workplace through Ephemeral Social Networks
# reference :  {'Live Social Semantics': ['H. Alani', 'M. Szomszor', 'C. Cattuto', 'W. Van den Broeck', 'G. Correndo', 'A. Barrat'], 'Find me if you can: improving geographical prediction with social and spatial proximity': ['L. Backstrom', 'E. Sun', 'C. Marlow'], 'From awareness to repartee: sharing location within social groups': ['L. Barkhuus', 'B. Brown', 'M. Bell', 'S. Sherwood', 'M. Hall', 'M. Chalmers'], 'Whozthat? evolving an ecosystem for context-aware mobile social networks': ['A. Beach', 'M. Gartrell', 'S. Akkala', 'J. Elston', 'J. Kelley', 'K. Nishimoto', 'B. Ray', 'S. Razgulin', 'K. Sundaresan', 'B. Surendar', 'M. Terada', 'R. Han'], 'Supporting informal communication via ephemeral interest groups': ['L. Brothers', 'J. Hollan', 'J. Nielsen', 'S. Stornetta', 'S. Abney', 'G. Furnas', 'M. Littman'], 'Dynamics of person-to-person interactions from distributed RFID sensor networks': ['C. Cattuto', 'W. Van den Broeck', 'A. Barrat', 'V. Colizza', 'J. F. Pinton', 'A. Vespignani'], 'Opportunistic spatial gossip over mobile social networks': ['A. Chaintreau', 'P. Fraigniaud', 'E. Lebhar'], 'Scalable and collaborative internet access for opportunistic people networks': ['L.J. Chen', 'T.K. Huang', 'C.L. Chiou'], 'Inferring Social Ties from Geographic Coincidences': ['D. Cr', 'all', 'L. Backstrom', 'D. Cosley', 'S. SuriD. Huttenlocher', 'J. Kleinberg'], 'Bridging the gap between physical location and online social networks': ['J. Cranshaw', 'E. Toch', 'J. Hong', 'A. Kittur', 'N. Sadeh.'], 'Social serendipity: mobilizing social software': ['N. Eagle', 'A. Pentl', ''], 'Inferring friendship network structure by using mobile phone data': ['N. Eagle', 'A. Pentl', '', 'David Lazer'], "Why some social network services work and others don't-Or: the case for object-centered sociality.": ['J. Engestrom'], 'Harvesting with SONAR: the value of aggregating social network information': ['I. Guy', 'M. Jacovi', 'E. Shahar', 'N. Meshulam', 'V. Soroka', 'S. Farrell'], 'Practical lessons from place lab': ['J. Hightower', 'A. LaMarca', 'I. Smith'], 'Ifind: a peer-to-peer application for real-time location monitoring on the mit campus': ['S. Huang', 'F. Proul', 'C. Ratti'], 'The quest for a killer app for opportunistic and delay tolerant networks: (invited paper)': ['A. Lindgren', 'P. Hui'], 'Are your facebook friends really your friends?': ['V.L Miller'], 'The familiar stranger: anxiety, comfort, and play in public places.': ['E. Paulos', 'E. Goodman'], 'User mobility for opportunistic ad-hoc networking': ['J. Su', 'A. Chin', 'A. Popivanova', 'A. Goel', 'E. de Lara'], "Who's viewed you?: the impact of feedback in a mobile locationsharing application": ['J. Tsai', 'P. Kelley', 'P.H. Drielsma', 'L. Cranor', 'J. Hong', 'N. Sadeh'], 'Supporting persistent social groups in ubiquitous computing environments using context-aware ephemeral group service': ['B. Wang', 'J. Bodily', 'S.K.S. Gupta'], 'Social Linking and Physical Proximity in a Mobile Location-based Service': ['B. Xu', 'A. Chin', 'H. Wang', 'H. Wang', 'L. Zhang']}
# authors :  Alvin Chin;Hao Wang;Bin Xu;Ke Zhang;Hao Wang;Lijun Zhu
# -------------------------------------------------------
# essayCode :  6921602
# title :  A semantic model for academic social network analysis
# reference :  {}
# authors :  Jie Hu;Mengchi Liu;Junchi Zhang
# -------------------------------------------------------
# essayCode :  5563074
# title :  Designing, Analyzing and Exploiting Stake-Based Social Networks
# reference :  {'The anatomy of a large-scale hypertextual Web search engine': ['S. Brin', 'L. Page'], 'Community structure in social and biological networks': ['M. Girvan', 'M. E. Newman']}
# authors :  Tsung-Ting Kuo;Jung-Jung Yeh;Chia-Jen Lin;Shou-De Lin
# -------------------------------------------------------
# essayCode :  10068643
# title :  PLMP: A Method to Map the Linguistic Markers of the Social Discourse onto its Semantic Network
# reference :  {'Critical questions for big data: Provocations for a cultural technological and scholarly phenomenon': ['D. Boyd', 'K. Crawford'], 'Part-of-speech tagging for Twitter: Annotation features and experiments': ['K. Gimpel', 'N. Schneider', "B. O'Connor", 'D. Das', 'D. Mills', 'J. Eisenstein'], 'Structural and semantic impact of online collective action': ['L. Badia', 'D Clementel', 'T. Erseghe', 'L. Iacovissi', 'M. Migliorini', 'B. G. Salvador Casara'], 'Pagerank beyond the web': ['D. F. Gleich'], 'Automated analysis of actor-topic networks on twitter: New approaches to the analysis of socio-semantic networks': ['I. Hellsten', 'L. Leydesdorff'], 'The rise of #climateaction in the time of the fridaysforfuture movement: a semantic network analysis': ['C. Suitner', 'L. Badia', 'D. Clementel', 'L. Iacovissi', 'M. Migliorini', 'B. G. Salvador Casara'], 'Improved part-of-speech tagging for online conversational text with word clusters': ['O. Owoputi', "B. O'Connor", 'C. Dyer', 'K. Gimpel', 'N. Schneider', 'N. Smith'], 'Introduction to the social and psycho-logical dynamics of collective action': ['M. Van Zomeren', 'A. Iyer'], 'Integrating who “we” are with what “we”(will not) stand for: A further extension of the social identity model of collective action': ['M. Van Zomeren', 'M. Kutlaca', 'F. Turner-Zwinkels'], 'The development and psychometric properties of LIWC2015': ['J. W. Pennebaker', 'R. L. Boyd', 'K. Jordan', 'K. Blackburn'], 'Such stuff as dreams are made on: Dream language LIWC norms and personality correlates': ['R. C. Hawkins', 'R. L. Boyd'], 'The big two dictionaries: Capturing agency and communion in natural language': ['A. Pietraszkiewicz', 'M. Formanowicz', 'M. Gustafsson Senden', 'R. L. Boyd', 'S. Sikstrom', 'S. Sczesny'], 'Social communication to improve group recognition in mobile networks': ['A. V. Guglielmi', 'L. Badia'], 'A distributed and scalable processing method based upon ADMM': ['T. Erseghe'], 'The effect of weight on community structure of networks': ['Y. Fan', 'M. Li', 'P. Zhang', 'J. Wu', 'Z. Di'], 'Bipartite network projection and personal recommendation': ['T. Zhou', 'J. Ren', 'M. Medo', 'Y. C. Zhang']}
# authors :  Tomaso Erseghe;Leonardo Badia;Lejla Dzanko;Caterina Suitner
# -------------------------------------------------------
# essayCode :  10068570
# title :  NetDriller-V3: A Powerful Social Network Analysis Tool
# reference :  {'Link prediction by network analysis': ['S. Afra', 'A. Aksac', 'T. Ozyer', 'R. Alhajj'], 'Netdriller version 2: A powerful social network analysis tool': ['S. Afra', 'T. Ozyer', 'J. Rokne'], 'Gephi: an open source software for exploring and manipulating networks': ['M. Bastian', 'S. Heymann', 'M. Jacomy'], 'Pajek-program for large network analysis': ['V. Batagelj', 'A. Mrvar'], 'The four dimensions of social network analysis: an overview of research methods applications and software tools': ['D. Camacho', 'A. Panizo-Lledot', 'G. Bello-Orgaz', 'A. Gonzalez-Pardo', 'E. Cambria'], 'Community-based scholar recommendation modeling in academic social network sites': ['J. Chen', 'Y. Tang', 'J. Li', 'C. Mao', 'J. Xiao'], 'The igraph software package for complex network research': ['G. Csardi', 'T. Nepusz'], 'The weka data mining software: an update': ['M. Hall', 'E. Frank', 'G. Holmes', 'B. Pfahringer', 'P. Reutemann', 'I. H. Witten'], 'Statnet: software tools for the representation visualization analysis and simulation of network data': ['M.S. H', 'cock', 'D.R. Hunter', 'C.T. Butts', 'S.M. Goodreau', 'M. Morris'], 'Netdriller: A powerful social network analysis tool': ['N. Koochakzadeh', 'A. Sarraf', 'K. Kianmehr', 'J. Rokne', 'R. Alhajj'], 'JGraphTa Java library for graph data structures and algorithms': ['D. Michail', 'J. Kinable', 'B. Naveh', 'J.V. Sichi'], 'Cytoscape: A software en-vironment for integrated models of biomolecular interaction networks': ['P. Shannon', 'A. Markiel', 'O. Ozier', 'N. S. Baliga', 'J. T. Wang', 'D. Ramage'], 'Predicting elections with twitter: What 140 characters reveal about political sentiment': ['A. Tumasjan', 'T. O. Sprenger', 'P. G. S', 'ner', 'I. M. Welpe'], 'Link prediction in social networks: the state-of-the-art': ['P. Wang', 'B. Xu', 'Y. Wu', 'X. Zhou']}
# authors :  Salim Afra;Tansel Özyer;Jon Rokne;Reda Alhajj
# -------------------------------------------------------
# essayCode :  9073019
# title :  Quantifying Triadic Closure in Multi-Edge Social Networks
# reference :  {'The strength of weak ties': ['M. S. Granovetter'], 'Clustering in weighted networks': ['T. Opsahl', 'P. Panzarasa'], 'Inference in curved exponential family models for networks': ['D. R. Hunter', 'M. S. H', 'cock'], 'Kinds of third-party effects on trust': ['R. S. Burt', 'M. Knez'], 'Persistence of close personal ties over a 12-year period': ['J. Martin', 'K.-T. Yeung'], 'New specifications for exponential random graph models': ['T. A. Snijders', 'P. E. Pattison', 'G. L. Robins', 'M. S. H', 'cock'], 'Adjusting for network size and composition effects in exponential-family random graph models': ['P. N. Krivitsky', 'M. S. H', 'cock', 'M. Morris'], 'An introduction to exponential random graph (p*) models for social networks': ['G. Robins', 'P. Pattison', 'Y. Kalish', 'D. Lusher'], 'Exponential-family random graph models for valued networks': ['P. N. Krivitsky'], 'ergm.count: Fit Simulate and Diagnose Exponential-Family Mod-els for Networks with Count Edges': [], 'An information flow model for conflict and fission in small groups': ['W. W. Zachary']}
# authors :  Laurence Brandenberger;Giona Casiraghi;Vahan Nanumyan;Frank Schweitzer
# -------------------------------------------------------
# essayCode :  5345436
# title :  SOCIAL-DTN: Why Social Networking Services is more fruitful to Mobile Delay-Tolerant Networks?
# reference :  {"What 's up 2.0: P2P Spontaneous Networking": ['M. Mani', 'A. Minh Nguyen', 'N. Crespi'], "What 's up: P2P Spontaneous Networking": ['M. Mani', 'A. Minh Nguyen', 'N. Crespi'], 'Measurement and analysis of online social networks': ['A. Mislove', 'M. Marcon', 'K. Gumm', 'i', 'P. Druschel', 'B. Bhattacharjee'], 'DTN-based Content Storage and Retrieval': ['J. Ott', 'M. Pitkänen'], 'Enabling Opportunistic storage for Mobile DTNs': ['M. Pitkänen', 'J. Ott'], 'Disconnection Tolerance for SIP-based Real-time Media Sessions': ['J. Ott', 'L. Xiaojun'], 'Routing issues in Opportunistic Networks': ['M. Conti', 'J. Crowcroft', 'S. Giordano', 'P. Hui', 'H. Nguyen', 'A. Passarella'], 'The Computer for the 21st Century': ['M. Weiser'], 'A survey and comparison of peer-to-peer overlay network schemes': ['E.K. Lua', 'J. Crowcroft', 'M. Pias', 'R. Sharma', 'S. Lim'], 'BUBBLE Rap: Social-based forwarding in Delay Tolerant Networks': ['P. Hui', 'J. Crowcroft', 'E. Yoneki']}
# authors :  Anh-Minh Nguyen;Noël Crespi
# -------------------------------------------------------
# essayCode :  5231943
# title :  Impact of Using Semantic Social Networks on Organizations
# reference :  {'Technology strategies in a complex environment': ['G.B. Dietrich', 'M.B. Shipley'], 'Flink: Semantic web technology for the extraction and analysis of social networks': ['P. Mika'], 'Designing communication systems for decentralized organizations: anew role for technical communicators': ['T.M. Skelton'], 'Ontologies are us: A unified model of social networks and semantics': ['P. Mika'], 'Rdf-based knowledge models for network management': ['J. Shen', 'Y. Yang'], 'Resource Description Framework': ['I. Herman', 'R. Swick', 'D. Brickley'], 'Semantic Web Road map': ['T. Berners-Lee'], 'Dublin Core Metadata Element Set': [], 'FOAF vocabulary specification': ['D. Brickley', 'L. Miller'], 'A software engineering approach to design and development of semantic web service applications': ['M. Brambilla', 'I. Celino', 'S. Ceri', 'D. Cerizza', 'E. Della Valle', 'F. Facca'], 'Social networks applied': ['S. Staab', 'P. Domingos', 'P. Mike', 'J. Golbeck', 'L. Ding', 'T. Finin'], 'Jena Documentation': []}
# authors :  Ali Fatalian;Zahra Amin Nayeri;Mohammad Azadnia
# -------------------------------------------------------
# essayCode :  6085932
# title :  Reconstruction of a social network graph from incomplete call detail records
# reference :  {'Teletraffic Modeling for Personal Communications Services': ['D. Lam', 'D.C. Cox', 'J. Widom'], 'Analysis and Visualization of Network Data using JUNG': ["J. O'Madadhain", 'D. Fisher', 'P. Smyth', 'S. White', 'Y.-B. Boey'], 'The Small World Problem': ['S. Milgram'], 'Emergence of Scaling in Random Networks': ['A.-L. Barabási', 'R. Albert'], 'Classification of Scale-Free Networks': ['K.-I. Goh', 'E. Oh', 'H. Jeong', 'B. Kahng', 'D. Kim'], 'Analyzing the Structure and Evolution of Massive Telecom Graphs': ['A.A. Nanavati'], 'Turning Telecommunication Call Details to Churn Prediction: a Data Mining Approach': ['C.-P. Wei', 'I-T. Chiu'], 'Formation of Triads in Mobile Telecom Networks': ['N.N. Krishna', 'M. Saravannan'], 'Inferring Friendship Network Structure by Using Mobile Phone Data': ['N. Eagle', 'A. Pentl', '', 'D. Lazer'], 'Structure and Tie Strengths in Mobile Communication Networks': ['J.-P. Onnela'], 'The Strength of Weak Ties': ['M.S. Granovetter'], 'De-anonymizing Social Networks': ['A. Narayannan', 'V. Shmatikov']}
# authors :  Mariusz Kamola;Ewa Niewiadomska-Szynkiewicz;Bartłomiej Cezary Piech
# -------------------------------------------------------
# essayCode :  9732080
# failed
# -------------------------------------------------------
# essayCode :  6085951
# title :  A degree centrality in multi-layered social network
# reference :  {'Friends and Neighbors on the Web,': ['Adamic L.A.', 'Adar E.'], 'How to search a social network,': ['Adamic L.A.', 'Adar E.'], 'Emergence of Scaling in Random Networks,': ['Barabási A.L.', 'Reka A.'], 'Extracting social networks and contact information from email and the Web,': ['Culotta A.', 'Bekkerman R.', 'McCallum A.'], 'Computer Networks as Social Networks,': ['Wellman B.']}
# authors :  Piotr Bródka;Krzysztof Skibicki;Przemysław Kazienko;Katarzyna Musiał
# -------------------------------------------------------
# essayCode :  5730301
# title :  A proposal to enhance cross-marketing via social networks by modelling and analyzing market basket like patterns across social network groups
# reference :  {'Mining association rules between sets of items in large databases': ['R. Agrawal', 'T. Imielinski', 'A. Swami'], 'The Link prediction problem for social networks Proceeding': ['D Liben-Nowell', 'J. Kleinberg'], 'Sentiment Analysis Hard But Worth It': ['Michelle de Haaff'], 'Mining Association Rules in Hypertext Databases': ['José Borges', 'Mark Levenev'], 'Opinion Observer: Analyzing and Comparing Opinions on the Web': ['B. Liu', 'M. Hu', 'J. Cheng'], 'Learning effective ranking functions for newsgroup search': ['W. Xi', 'J. Lind', 'E. Brill'], 'Alternative interest measures for mining associations in databases': ['Edward R. Omiecinski'], 'Exploring Patterns of Social Commonality Among File Directories at Work': ['John C. Tang', 'Fei Wu', 'Mark A. Smith', 'Clemens Drews Tessa', 'A. Lau', 'Alison E. Sue']}
# authors :  C Bharath;Jai Ganesh
# -------------------------------------------------------
# essayCode :  5992682
# title :  Taiwan Academic Network Discussion via Social Networks Analysis Perspective
# reference :  {}
# authors :  Chen-Shu Wang;I-Hsien Ting;Yu-Chieh Li
# -------------------------------------------------------
# essayCode :  6425619
# title :  Predicting Social Network Measures Using Machine Learning Approach
# reference :  {'The link prediction problem for social networks, ': ['D. L. Nowell', 'J. Kleinberg'], 'Link mining: a survey, ': ['L. Getoor', 'C. P. Diehl'], 'Scalable Link Prediction on Multidimensional Networks, ': ['G. Rossetti', 'M. Berlingerio', 'F. Giannotti'], 'Statistical relational learning for link prediction, ': ['A. Popescul', 'R. Popescul', 'L. H. Ungar'], 'Learning and predicting the evolution of social networks, ': ['B. Bringmann', 'M. Berlingerio', 'F. Bonchi', 'A. Gionis'], 'Connectivity and inference problems for temporal networks, ': ['D. Kempe', 'J. Kleinberg', 'A. Kumar'], 'The WEKA data mining software: an update, ': ['M. Hall', 'E. Frank', 'G. Holmes', 'B. Pfahringer', 'P. Reutemann', 'I. H. Witten'], 'Ora: Organization risk analyzer, ': ['K. M. Carley'], 'A study of Cross-Validation and bootstrap for accuracy estimation and model selection, ': ['R. Kohavi'], 'A distance measure between attributed relational graphs for pattern recognition.': ['A. Sanfeliu', 'K.-S. Fu'], 'Modelling social network evolution, ': ['R. Michalski', 'S. Palus', 'P. Bródka', 'P. Kazienko', 'K. Juszczyszyn']}
# authors :  Radoslaw Michalski;Przemyslaw Kazienko;Dawid Król
# -------------------------------------------------------
# essayCode :  5231831
# title :  Identify Implicit Social Network by RST/FL Framework
# reference :  {'Privacy Protection in Social Network Data Disclosure Based on Granular Computing': ['D.-W. Wang', 'Churn-Jung Liau', 'Tsan-sheng Hsu'], 'Applications of Semantic Web Methodologies and Techniques to Social Networks and Social Websites': ['S. Kinsella', 'J. Breslin', 'A. Passant', 'S. Decker'], 'Context-aware system for proactive personalized service based on context history': ['J. Hong', 'E.-H. Suh', 'J. Kim', 'S. Kim'], 'Community Mining from Multi-relational Networks': ['D. Cai', 'Z. Shao', 'X. He', 'X. Yan', 'J. Han'], 'Conceptual modeling for data and knowledge management': ['G. W. Mineau', 'R. Missaoui', 'R. Godinx'], 'Logical foundations of object-oriented and frame-based languages': ['M. Kifer', 'G. Lausen', 'J. Wu'], 'Expert Finding for eCollaboration Using FOAF with RuleML Rules': ['J. Li', 'H. Boley', 'V. C. Bhavsar', 'J. Mei']}
# authors :  Hong Feng Lai
# -------------------------------------------------------
# essayCode :  6425780
# title :  Measuring the Importance of Users in a Social Network Based on Email Communication Patterns
# reference :  {'Communication networks from the enron email corpus ': ['J. Diesner', 'T. Frantz', 'K. Carley'], 'Mining email social networks': ['Ch. Bird', 'A. Gourley', 'P. Devanbu', 'M. Gaertz', 'A. Swaminathan'], 'Rank aggregation methods for the web, ': ['C. Dwork', 'R. Kumar', 'M. Naor', 'D. Sivakumar'], 'Generalized distances between rankings, ': ['R. Kumar', 'S. Vassilvitskii'], 'Methods for comparing rankings of search engine results, ': ['J. Bar-Ilan', 'M. Mat-Hassan', 'M. Levene'], 'Comparing top k lists, ': ['R. Fagin', 'R. Kumar', 'D. Sivakumar'], 'Comparing rankings of search results on the web, ': ['Judit', 'Bar-Ilan']}
# authors :  Pawel Lubarski;Mikolaj Morzy
# -------------------------------------------------------
# essayCode :  9073317
# title :  Strengthening Social Networks Analysis by Networks Fusion
# reference :  {'Network structure from rich but noisy data ': ['M E J Newman'], 'Similarity networks fusion for aggregating data types on a genomic scale. ': ['B Wang', 'A M Mezlini', 'F Demir'], 'Inferring microbial interaction networks based on consensus similarity network fusion. ': ['X P Jiang', 'X H. Hu'], 'Shifu: Deep Learning Based Advisor-advisee Relationship Mining in Scholarly Big Data': ['Wei Wang', 'Jiaying Liu', 'Feng Xia'], 'PCT: Partial Co-Alignment of Social Networks': ['J Zhang', 'P S. Yu'], 'Multilevel Network Alignment': ['S Zhang', 'H Tong', 'R Maciejewski'], 'ABNE: An Attention Based Network Embedding for User Alignment Across Social Networks': ['L Liu', 'Y Zhang', 'S Fu'], 'Structural reducibility of multilayer networks ': ['D M De', 'V Nicosia', 'A Arenas'], 'Social Network Extraction and High Value Individual (HVI) Identification within Fused Intelligence Data': ['A Farasat', 'G Gross', 'R Nagi'], 'Community detection combined with multi-dimensional relationships in location-based social networks': ['WH Gong', 'YQ Chen', 'XB Pei', 'LH. Yang'], 'Greedy function approximation: a gradient boosting machine ': ['J H Friedman']}
# authors :  Feiyu Long;Nianwen Ning;Chenguang Song;Bin Wu
# -------------------------------------------------------
# essayCode :  6785770
# title :  A HITS-based POI recommendation algorithm for Location-Based Social Networks
# reference :  {'A recommendation system for spots in location-based online social networks': ['B. Berjani', 'T. Strufe'], 'Towards the next generation of recommender systems: A survey of the state-of-the-art and possible extensions': ['G. Adomavicius', 'A. Tuzhilin'], 'A survey paper on recommender systems': ['D. Almazro', 'G. Shahatah', 'L. Albdulkarim', 'M. Kherees', 'R. Martinez', 'W. Nzoukou'], 'A random walk around the city: New venue recommendation in location-based social networks': ['A. Noulas', 'S. Scellato', 'N. Lathia', 'C. Mascolo'], 'Feedback effects between similarity and social influence in online communities': ['D. Cr', 'all', 'D. Cosley', 'D. Huttenlocher', 'J. Kleinberg', 'S. Suri'], 'Trustwalker: A random walk model for combining trust-based and item-based recommendation': ['M. Jamali', 'M. Ester'], 'Location recommendation in location-based social networks': ['M. Ye', 'P. Yin', 'W.-C. Lee'], 'Mining interesting locations and travel sequences from gps trajectories': ['Y. Zheng', 'L. Zhang', 'X. Xie', 'W.-Y. Ma'], 'Collaborative location and activity recommendations with gps history data': ['V. W. Zheng', 'Y. Zheng', 'X. Xie', 'Q. Yang'], 'Clr: A collaborative location recommendation framework based on co-clustering': ['K. W.-T. Leung', 'D. L. Lee', 'W.-C. Lee'], 'Urban point-of-interest recommendation by mining user check-in behaviors': ['J. J.-C. Ying', 'E. H.-C. Lu', 'W.-N. Kuo', 'V. S. Tseng'], 'Exploiting place features in link prediction on location-based social networks': ['S. Scellato', 'A. Noulas', 'C. Mascolo'], 'Socio-spatial properties of online location-based social networks': ['S. Scellato', 'A. Noulas', 'R. Lambiotte', 'C. Mascolo'], 'Mining user mobility features for next place prediction in location-based services': ['A. Noulas', 'S. Scellato', 'N. Lathia', 'C. Mascolo'], 'Authoritative sources in a hyperlinked environment': ['J. M. Kleinberg']}
# authors :  Xuelian Long;James Joshi
# -------------------------------------------------------
# essayCode :  9336563
# title :  Capacity Management Protocol for a Structured P2P-based Online Social Network
# reference :  {'Libresocial: A peer-to-peer framework for online social networks': ['K. Graffi', 'N. Masinde'], 'Practical security in P2P-based social networks': ['K. Graffi', 'P. Mukherjee', 'B. Menges', 'D. Hartung', 'A. Kovacevic', 'R. Steinmetz'], 'LifeSocial.KOM: A P2P-based Platform for Secure Online Social Networks': ['K. Graffi', 'C. Gross', 'P. Mukherjee', 'A. Kovacevic', 'R. Steinmetz'], 'LifeSocial. KOM: A secure and P2P-based solution for online social networks': ['K. Graffi', 'C. Gross', 'D. Stingl', 'D. Hartung', 'A. Kovacevic', 'R. Steinmetz'], 'DECENT: A decentralized architecture for enforcing privacy in online social networks': ['S. Jahid', 'S. Nilizadeh', 'P. Mittal', 'N. Borisov', 'A. Kapadia'], 'Lotusnet: Tunable privacy for distributed online social network services': ['L. M. Aiello', 'G. Ruffo'], 'Scal-ability Issues in Online Social Networks': ['T. Maqsood', 'O. Khalid', 'R. Irfan', 'S. A. Madani', 'S. U. Khan'], 'Exploring peer heterogeneity: Towards understanding and application': ['Z. Yang', 'Y. Xing', 'F. Xiao', 'Z. Qu', 'X. Li', 'Y. Dai'], 'Heterogeneity and load balance in distributed hash tables': ['P. B. Godfrey', 'I. Stoica'], 'Flexible replica placement for optimized p2p backup on heterogeneous unreliable machines': ['P. Skowron', 'K. Rzadca'], 'Mechanism design for dynamic p2p streaming': ['G. Tian', 'Y. Xu', 'Y. Liu', 'K. Ross'], 'Structured overlay for heterogeneous environments: Design and evaluation of oscar': ['S. Girdzijauskas', 'A. Datta', 'K. Aberer'], 'Overlay design mechanisms for heterogeneous large-scale dynamic p2p systems': ['V. Darlagiannis', 'A. Mauthe', 'R. Steinmetz'], 'Chord: A scalable peer-to-peer lookup service for internet applications': ['I. Stoica', 'R. Morris', 'D. Karger', 'M. F. Kaashoek', 'H. Balakrishnan'], 'Pastry: Scalable decentralized object location and routing for large-scale peer-to-peer systems': ['A. Rowstron', 'P. Druschel'], 'Kademlia: A peer-to-peer information system based on the xor metric': ['P. Maymounkov', 'D. Mazieres', 'P. Druschel', 'M. F. Kaashoek', 'A. I. T. Rowstron'], 'Peer-to-peer based social networks: A comprehensive survey': ['N. Masinde', 'K. Graffi'], 'DS2: A DHT-based substrate for distributed services': ['L. Li', 'X. Xu', 'J. Wang', 'W. Wang'], 'Adding capacity-aware storage indirection to homogeneous distributed hash tables': ['P. Wette', 'K. Graffi'], 'Survey on load balancing in peer-to-peer distributed hash tables': ['P. Felber', 'P. Kropf', 'E. Schiller', 'S. Serbu'], 'A scalable content-addressable network': ['S. Ratnasamy', 'P. Francis', 'M. H', 'ley', 'R. Karp', 'S. Shenker'], 'Data Replication Strategies in P2P Systems: A Survey': ['E. Spaho', 'L. Barolli', 'F. Xhafa'], 'Fault-tolerant p2p networks: how dependable is greedy routing': ['S. Serbu', 'P. Kropf', 'P. Felber'], 'HyperCuP - Hypercubes Ontologies and Efficient Search on Peer-to-Peer Networks': ['M. Schlosser', 'M. Sintek', 'S. Decker', 'W. Nejdl', 'G. Moro', 'M. Koubarakis'], 'Distributed maintenance of mutable information for virtual environments': ['V. Darlagiannis', 'A. Mauthe', 'N. Liebau', 'R. Steinmetz'], 'Dynamic nodeid based heterogeneity aware p2p system': ['K. Kim'], 'Consistent key mapping in structured overlays': ['A. Haeberlen', 'J. Hoye', 'A. Mislove', 'P. Druschel'], 'Towards Benchmarking of Structured Peer-to-Peer Overlays for Network Virtual Environments': ['A. Kovacevic', 'K. Graffi', 'S. Kaune', 'C. Leng', 'R. Steinmetz'], 'Systematic Evaluation of LibreSocial-A Peer-to-Peer Framework for Online Social Networks': ['N. Masinde', 'L. Khitman', 'I. Dlikman', 'K. Graffi']}
# authors :  Newton Masinde;Sebastian Bischoff;Kalman Graffi
# -------------------------------------------------------
# essayCode :  7752251
# title :  Priority rank model for social network generation
# reference :  {'Power-law distributions in empirical data': ['A. Clauset', 'C. R. Shalizi', 'M. E. Newman'], 'Graphs over time: densification laws shrinking diameters and possible explanations': ['J. Leskovec', 'J. Kleinberg', 'C. Faloutsos'], 'On the evolution of random graphs': ['P. Erdös', 'A. Rényi'], 'Collective dynamics of ‘small-world’ networks': ['D. J. Watts', 'S. H. Strogatz'], 'Emergence of scaling in random networks': ['A.-L. Barabási', 'R. Albert'], 'A model for the generation of social network graphs': ['M. Conti', 'A. Passarella', 'F. Pezzoni'], 'A dynamic model of social network formation': ['B. Skyrms', 'R. Pemantle'], 'Modeling bursts and heavy tails in human dynamics': ['A. Vázquez', 'J. G. Oliveira', 'Z. Dezso', 'K.-I. Goh', 'I. Kondor', 'A.-L. Barabási'], 'Stochastic queueing-theory approach to human dynamics': ['J. Walraevens', 'T. Demoor', 'T. Maertens', 'H. Bruneel'], 'Time-varying priority queuing models for human dynamics': ['H.-H. Jo', 'R. K. Pan', 'K. Kaski'], 'Information overload and human priority queuing': ['A. Sharma', 'K. P. Jagannathan', 'L. R. Varshney']}
# authors :  Mikołaj Morzy;Przemysław Kazienko;Tomasz Kajdanowicz
# -------------------------------------------------------
# essayCode :  5231915
# title :  Predicting Links in Social Networks Using Text Mining and SNA
# reference :  {'Evolution of the social network of scientific collaboration': ['A.L. Barabasi', 'H. Jeong', 'Z. Neda', 'E. Ravasz', 'A. Schubert', 'T. Vicsek'], 'Emergence of scaling in random networks': ['A.L. Barabasi', 'R. Albert'], 'Temporality in Link Prediction: Understanding Social Complexity': ['Potgieter K. A. April', 'R. J. E. Cooke', 'I. O. Osunmakinde'], 'Semantic analytics on social networks: Experiences in addressing the problem of conflict of interest detection': ['Aleman-Meza', 'M. Nagarajan', 'C. Ramakrishnan', 'A. Sheth', 'I. Arpinar', 'L. Ding', 'P. Kolari'], 'Neural Networks for Pattern Recognition': ['M. Bishop'], 'Textvis: An integrated visual environment for text mining In Principles of Data Mining and Knowledge Discovery': ['L', 'au R. Feldman', 'Y. Aumann', 'M. Fresko', 'Y. Lindell', 'O. Liphstat', 'O. Zamir'], 'An Algorithmic Approach to Social Networks': ['Liben-Nowell'], 'The link prediction problem for social networks': ['D. Liben-Nowell', 'J. Kleinberg'], 'The Link Prediction Problem for Social Networks': ['D. Liben-Nowell', 'J. Kleinberg'], 'Document ranking and the vector space model': ['D.L. Lee', 'H. Chuang', 'K. Seamons'], 'Data Mining: Practical Machine Learning Tools and Techniques': ['I. Witten', 'E. Frank'], 'The Small-World Phenomenon: An Algorithmic Perspective': ['J. Kleinberg'], 'Friends and Neighbors on the Web': ['L.A. Adamic', 'E. Adar'], 'Link Mining: A Survey': ['L. Getoor', 'C. Diehl'], 'The structure of scientific collaboration networks': ['M. E. J. Newman'], 'Assortative Mixing in Networks': ['M. E. J. Newman'], 'The structure and function of complex networks': ['M. E. J. Newman'], 'Social Network Analysis: Methods and Applications': ['S. Wasserman', 'K. Faust'], 'A critical analysis of vector space model for information retrieval': ['V.V. Raghavan', 'S. K. M. A. Wongcritical'], 'Co-Authorship Networks in the Digital Library Research Community': ['X. Liu', 'J. Bollen', 'M.L. Nelson', 'H. Van de Sompel'], 'Link Prediction Approach to Collaborative Filtering': ['Z. Huang', 'X. Li', 'H. Chen']}
# authors :  Alon Bartal;Elan Sasson;Gilad Ravid
# -------------------------------------------------------
# essayCode :  9381341
# title :  A Theoretical Approach for Discovery of Friends from Directed Social Graphs
# reference :  {'Multitask learning for blackmarket tweet detection': ['U. Arora'], 'Semi-supervised learning and graph neural networks for fake news detection': ['A. Benamira'], 'Knowledge discovery from social graph data': ['P. Braun'], 'A new framework for mining weighted periodic patterns in time series databases': ['A.K. Ch', 'a'], 'DeepGx: deep learning using gene expression for cancer classification': ['J. De Guia'], 'Mining personal media thresholds for opinion dynamics and social influence': ['C. Doyle'], 'Social network mining for recommendation of friends based on music interests': ['C. Fan'], 'Mining frequent patterns from human interactions in meetings using directed acyclic graphs': ['A. Fariha'], 'Supporting social information discovery from big uncertain social key-value data via graph-like metaphors': ['C.S.H. Hoi'], 'Big data mining of social networks for friend recommendation': ['F. Jiang'], 'Finding popular friends in social networks': ['F. Jiang'], 'A data analytic algorithm for managing querying and processing uncertain big data in cloud environments': ['F. Jiang', 'C.K. Leung'], 'Emerging trends issues and challenges in Internet of Things big data and cloud computing': ['A. Kobusinska'], 'Big data analysis and mining': ['C.K. Leung'], 'Mathematical model for propagation of influence in a social network': ['C.K. Leung'], 'Uncertain frequent pattern mining': ['C.K. Leung'], 'Exploring social networks: a frequent pattern visualization approach': ['C.K. Leung', 'C.L. Carmichael'], 'FpVAT: a visual analytic tool for supporting frequent pattern mining': ['C.K. Leung', 'C.L. Carmichael'], 'FpViz: a visualizer for frequent pattern mining': ['C.K. Leung', 'C.L. Carmichael'], 'A machine learning approach for stock price prediction': ['C.K. Leung'], 'Big data analytics of social network data: Who cares most about you on Facebook?': ['C.K. Leung'], 'Efficient and flexible compression of very sparse networks of big data': ['C.K. Leung'], 'Fast algorithms for frequent itemset mining from uncertain data': ['C.K. Leung'], 'Flexible compression of big data': ['C.K. Leung'], 'Knowledge discovery from big social key-value data': ['C.K. Leung'], 'Mining ‘following’ patterns from big but sparsely distributed social network data': ['C.K. Leung'], 'Mining ‘following’ patterns from big sparse social networks': ['C.K. Leung'], 'Parallel social network mining for interesting ‘following’ patterns': ['C.K. Leung'], 'Visual analytics of social networks: mining and visualizing co-authorship networks': ['C.K. Leung'], 'A data science solution for mining interesting patterns from uncertain big data': ['C.K. Leung', 'F. Jiang'], 'Big data analytics of social networks for the discovery of ‘following’ patterns': ['C.K. Leung', 'F. Jiang'], 'Efficient mining of ‘following’ patterns from very big but sparse social networks': ['C.K. Leung', 'F. Jiang'], 'Big data analytics of Twitter data and its application for physician assistants: who is talking about your profession in Twitter?': ['M. Mai'], 'How much data do we create every day? The mind-blowing stats everyone should read': ['B. Marr'], 'An evolutionary approach for detecting communities in social networks': ['K. Ozturk'], 'RelExt: relation extraction using deep learning approaches for cybersecurity knowledge graph improvement': ['A. Pingle'], 'Applying k-vertex cardinality constraints on a Neo4j graph database': ['M. Sestak'], 'A theoretical approach to discover mutual friendships from social graph networks': ['S.P. Singh'], 'g12vec: learning feature representation using graphlets for directed networks': ['K. Tu'], 'A fast and efficient incremental approach toward dynamic community detection': ['N. Zarayeneh', 'A. Kalyanaraman']}
# authors :  Sehaj P. Singh;Carson K. Leung
# -------------------------------------------------------
# essayCode :  5992635
# title :  Identifying Structural Heterogeneities between Online Social Networks for Effective Word-of-Mouth Marketing
# reference :  {}
# authors :  Kai-Yu Wang;Narongsak Thongpapanl;Hui-Ju Wu;I-Hsien Ting
# -------------------------------------------------------
# essayCode :  9377088
# title :  Social Network measures association with social and intelligent behaviors in Dolphin network
# reference :  {'Social Network Analysis: Applications to Primate and Cetacean Societies': ['Margaret Stanton', 'Janet Mann'], 'Social network analysis of animal behaviour: a promising tool for the study of sociality': ['Tina Wey', 'Daniel T. Blumstein', 'Weiwei Shen', 'Ferenc Jordán'], 'Animal social networks: an introduction': ['J. Krause', 'D. Lusseau', 'R James'], 'Evidence for social role in a dolphin social network': ['D Lusseau'], 'Identifying the role that animals play in their social networks': ['Lusseau David', 'M. E. J. Newman'], 'Generalized Louvain method for community detection in large networks': ['P. De Meo', 'E. Ferrara', 'G. Fiumara', 'A. Provetti'], 'Identifying Gender Specific Interaction Pattern: A Social Network Approach': ['S. Garg', 'T. K. G', 'hi', 'B. K. Panigrahi'], 'Why Are Male Social Relationships Complex in the Doubtful Sound Bottlenose Dolphin Population?': ['D Lusseau'], "Collective dynamics of 'small-world' networks": ['DJ Watts', 'SH Strogatz'], 'Quantifying the influence of sociality on population structure in bottlenose dolphins': ['D. Lusseau', 'B. Wilson', 'P.S. Hammond', 'K. Grellier', 'J. W. Durban', 'K. M. Parsons'], 'The average path length of scale free networks': ['Fei Chen', 'Xiufeng Wang', 'Zhuzhi Yuan'], 'Comparative social network analysis in a leaf-roosting bat': ['G Chaverri'], 'The bottlenose dolphin community of Doubtful Sound features a large proportion of long-lasting associations': ['D. Lusseau', 'K. Schneider', 'O. J. Boisseau', 'P. Haase', 'E. Slooten', 'S. M. Dawson'], 'Gephi: An Open Source Software for Exploring and Manipulating Networks': ['Mathieu Bastian', 'Sebastien Heymann', 'Mathieu Jacomy'], 'ForceAtlas2. a Continuous Graph Layout Algorithm for Handy Network Visualization Designed for the Gephi Software': ['M Jacomy', 'T Venturini', 'S Heymann', 'M Bastian'], 'Fast unfolding of communities in large networks': ['Vincent D Blondel', 'Jean-Loup Guillaume', 'Renaud Lambiotte', 'Etienne Lefebvre'], 'A faster algorithm for betweenness centrality': ['Ulrik Br', 'es'], 'Authoritative Sources in a Hyperlinked Environment': ['Jon M. Kleinberg'], 'How Can Social Network Analysis Improve the Study of Primate Behavior?': ['Cédric Sueur', 'Arm', 'Jacobs', 'Frédéric Amblard', 'Odile Petit', 'Andrew King'], 'A social network analysis of primate groups': ['Claudia Kasper', 'Bernhard Voelkl']}
# authors :  Sangita Garg;Tapan K. Gandhi;B.K. Panigrahi
# ***********************   Page  2   ***********************************
# -------------------------------------------------------
# essayCode :  9421847
# title :  The Analysis on the Role of Social Network in the Field of Anti-Terrorism Take the "East Turkistan" Organization as an Example
# reference :  {'Mapping networks of terrorist cells': ['V E. Krebs'], 'Centrality in social networks: Conceptual clarification': ['C. Freeman Linton'], 'Breaking Al Qaeda Cells: A Mathematical Analysis of Counterterrorism Operations (A Guide for Risk Assessment and Decision Making) ': ['David J. Farley'], 'About modelling of complex networks with applications to terrorist group modelling': ['Drazen Penzar', 'Armano Srbljinovic'], 'Social network analysis of criminal organization structure': ['Chen Peng', 'Yuan Hongyong'], 'The application of social network analysis in anti-terrorism ': ['Li Benxian', 'Li Mengjun', 'Sun Duoyong', 'Chi Yan', 'Fan Linjun']}
# authors :  Xiaoyuan Liu;Tianyang Sun;Fanliang Bu;Hang Qin
# -------------------------------------------------------
# essayCode :  6921575
# title :  Constructing social networks from semi-structured chat-log data
# reference :  {}
# authors :  Sude Tavassoli;Markus Moessner;Katharina Anna Zweig
# -------------------------------------------------------
# essayCode :  9381448
# title :  Social Capital Games as A Framework for Social Structural Pattern Emergence
# reference :  {'Community structure in social and biological networks': ['M. Girvan', 'M. E. Newman'], 'Collective dynamics of ‘small-world’ networks': ['D. J. Watts', 'S. H. Strogatz'], 'Structure and dynamics of core/periphery networks': ['P. Csermely', 'A. London', 'L.- Y. Wu', 'B. Uzzi'], 'The network structure of social capital': ['R. S. Burt'], 'Social capital in the creation of human capital': ['J. S. Coleman'], 'Relationship rewards': ['D. G. Myers'], 'The forms of capital': ['P. Bourdieu'], 'Structural holes and good ideas': ['R. S. Burt'], 'Social capital: Prospects for a new concept': ['P. S. Adler', 'S.-W. Kwon'], 'How to build your network? a structural analysis': ['A. Moskvina', 'J. Liu'], 'Dynamic relationship building: exploitation versus exploration on a social network': ['B. Yan', 'Y. Chen', 'J. Liu'], 'A strategic model of social and economic networks': ['M. O. Jackson', 'A. Wolinsky'], 'An economic model of friendship: Homophily minorities and segregation': ['S. Currarini', 'M. O. Jackson', 'P. Pin'], 'From the periphery to the core: Information brokerage in an evolving network': ['B. Yan', 'Y. Liu', 'J. Liu', 'Y. Cai', 'H. Su', 'H. Zheng'], 'Balancing the pain and gain of hobnobbing: Utility-based network building over atributed social networks': ['Y. Cai', 'H. Zheng', 'J. Liu', 'B. Yan', 'H. Su', 'Y. Liu'], 'Dynamic network formation with incomplete information': ['Y. Song', 'M. van der Schaar'], 'On the maximization of influence over an unknown social network': ['B. Yan', 'K. Song', 'J. Liu', 'F. Meng', 'Y. Liu', 'H. Su'], 'The strength of weak ties': ['M. S. Granovetter'], 'Trust and cooperation: Social capital and community resource management': ['J. Bouma', 'E. Bulte', 'D. van Soest'], 'Social capital and community resilience': ['D. P. Aldrich', 'M. A. Meyer'], 'Social capital friendship networks and youth unemployment': ['M. Hallsten', 'C. Edling', 'J. Rydgren'], 'Meeting strangers and friends of friends: How random are social networks?': ['M. O. Jackson', 'B. W. Rogers'], 'Microscopic evolution of social networks': ['J. Leskovec', 'L. Backstrom', 'R. Kumar', 'A. Tomkins'], 'A micro-foundation of social capital in evolving social networks': ['A. M. Alaa', 'K. Ahuja', 'M. van der Schaar'], 'Random graphs with arbitrary degree distributions and their applications': ['M. E. Newman', 'S. H. Strogatz', 'D. J. Watts'], 'Community membership identification from small seed sets': ['I. M. Kloumann', 'J. M. Kleinberg'], 'Supervised random walks: predicting and recommending links in social networks': ['L. Backstrom', 'J. Leskovec'], 'Emergence of norms through social learning': ['S. Sen', 'S. Airiau'], 'To be big picture thinker or detail-oriented? utilizing perceived gist information to achieve efficient convention emergence with bilateralism and multilateralism': ['S. Hu', 'C.-w. Leung', 'H.-f. Leung', 'J. Liu'], 'Efficient norm emergence through experiential dynamic punishment': ['S. Mahmoud', 'N. Griffiths', 'J. Keppens', 'M. Luck'], 'A decentralized approach for convention emergence in multi-agent systems': ['M. Mihaylov', 'K. Tuyls', 'A. Nowe'], 'Multi-agent reinforcement learning in sequential social dilemmas': ['J. Z. Leibo', 'V. Zambaldi', 'M. Lanctot', 'J. Marecki', 'T. Graepel'], 'Inequity aversion improves cooperation in intertemporal social dilemmas': ['E. Hughes', 'J. Z. Leibo', 'M. Phillips', 'K. Tuyls', 'E. Duenez-Guzman', 'A. G. Castaneda', 'I. Dunning', 'T. Zhu', 'K. McKee', 'R. Koster'], 'Evolving intrinsic motivations for altruistic behavior': ['J. X. Wang', 'E. Hughes', 'C. Fern', 'o', 'W. M. Czarnecki', 'E. A. Duenez-Guzman', 'J. Z. Leibo'], 'Rem: From structural entropy to community structure deception': ['Y. Liu', 'J. Liu', 'Z. Zhang', 'L. Zhu', 'A. Li'], 'Core-periphery organization of complex networks': ['P. Holme'], 'Social structure emergence: A multi-agent reinforcement learning framework for relationship building': ['Y. Chen', 'J. Liu', 'H. Zhao', 'H. Su'], 'Fast random walk with re ...
# authors :  Yang Chen;Jiamou Liu
# -------------------------------------------------------
# essayCode :  9069131
# title :  The Analysis on Power Migration: The Relationship Between Progeny Networks and Geographical Interlocking Shareholdings
# reference :  {'The economic effect of interlocking directorates in Italy: new evidence using centrality measures': ['E. Croci', 'R. Grassi'], 'Lost in space: the geography of corporate interlocking directorates 1': ['C. Kono', 'D. Palmer', 'R. Friedl', 'M. Zafonte'], 'Defining the social capital of the board of directors: An exploratory study': ['G. J. Nicholson', 'M. Alex', 'er', 'G. C. Kiel'], 'Exploratory social network analysis of affiliation networks of Indian listed companies': ['C. P. Sankar', 'K. Asokan', 'K. S. Kumar'], 'White Collars and Black Ties Interlocking Social Circles of Elite Corporate Offenders': ['G. Bichler', 'A. Schoepfer', 'S. Bush'], 'Governance networks: Interlocking directorships of corporate and nonprofit boards': ['L. Vidovich', 'J. Currie'], 'Network of Board of Directors in Mexican Corporations: A Social Network Analysis': ['C. R. Avina-Vazquez', 'S. Uddin'], 'The community structure of the European network of interlocking directorates 2005– 2010': ['E. M. Heemskerk', 'F. Daolio', 'M. Tomassini'], "The social field of the European corporate elite: a network analysis of interlocking directorates among Europe's largest corporate boards": ['E. M. Heemskerk'], "Are Latin America's corporate elites transnationally interconnectedƒ A network analysis of interlocking directorates": ['J. Cardenas'], 'The Corporate Network in Germany 1896-2010': ['P. Windolf'], 'The interpretation of statistical maps': ['P. A. Moran'], 'The analysis of spatial association by use of distance statistics': ['A. Getis', 'J. K. Ord']}
# authors :  Jun-Home Chen;Jyi-Shane Liu
# -------------------------------------------------------
# essayCode :  7104838
# failed
# -------------------------------------------------------
# essayCode :  8256390
# title :  Study on the social networks based on Japanese social events from name card data
# reference :  {'The influence of culture on international business negotiations': ['B. J. Hurn'], 'Japanese national culture as a basis for understanding japanese business practices': ['J. B. Ford', 'E. D. Honeycutt'], 'Event-based social networks: linking the online and offline social worlds': ['X. Liu', 'Q. He', 'Y. Tian', 'W.-C. Lee', 'J. McPherson', 'J. Han'], 'Structure and evolution of co-authorship network in an interdisciplinary research field': ['P. Liu', 'H. Xia'], 'Building and analyzing a global co-authorship network using google scholar data': ['Y. Chen', 'C. Ding', 'J. Hu', 'R. Chen', 'P. Hui', 'X. Fu'], 'Interpersonal and inter-organizational networks in the performing arts: The case of project-based organizations in the live music industry': ['S. R. Sedita'], 'Social capital structural holes and the formation of an industry network': ['G. Walker', 'B. Kogut', 'W. Shan'], 'Network evolution and the spatiotemporal dynamics of knowledge sourcing': ['R. Huggins', 'H. Izushi', 'D. Prokop', 'P. Thompson'], 'Network structure and industrial clustering dynamics in the aerospace industry': ['E. Turkina', 'A. Van Assche', 'R. Kali'], 'Community discovery in multi-mode networks': ['I. Jones', 'L. Tang', 'H. Liu'], 'Modularity and community structure in networks': ['M. E. Newman']}
# authors :  Ling Tan;Shihan Wang;Takao Terano
# -------------------------------------------------------
# essayCode :  7403655
# title :  Linear threshold model in temporal networks — Seed selection for social influence
# reference :  {'Temporal networks': ['P. Holme', 'J. Saramäki'], 'Small but slow world: How network topology and burstiness slow down spreading': ['M. Karsai', 'M. Kivelä', 'R. K. Pan', 'K. Kaski', 'J. Kertész', 'A.-L. Barabási'], 'Seed selection for spread of influence in social networks: Temporal vs. static approach': ['R. Michalski', 'T. Kajdanowicz', 'P. Bródka', 'P. Kazienko']}
# authors :  Radosław Michalski
# -------------------------------------------------------
# essayCode :  8653787
# title :  “SMART COLLEGE”- Study of Social Network and IoT Convergence
# reference :  {'Trust-Based Service Management for Social Internet of Things Systems': ['Ing-Ray Chen', 'Fenye Bao', 'Jia Guo'], 'Smartbuddy: defining Human behaviors using big data analytics in Social internet of things': ['An', 'Paul', 'Awais Ahmad', 'M. mazhar rathore', 'sohail Jabbar'], 'Social Internet of Things: The potential of the Internet of Things for defining human behaviours': ['Antonio J. Jara', 'Yann Bocchi', 'Dominique Genoud'], 'The Cluster Between Internet of Things and Social Networks: Review and Research Challenges': ['Antonio M. Ortiz', 'Dina Hussein', 'Soochang Park', 'Son N. Han', 'Noel Crespi'], 'Siot: Giving a social structure to the internet of things': ['L. Atzori', 'A. Iera', 'G. Morabito'], 'Trustworthiness Management in the Social Internet of Things': ['Michele Nitti', 'Roberto Girau', 'Luigi Atzori'], 'Implementation of an experimental platform for the Social Internet of Things': ['Roberto Girau', 'Michele Nitti', 'Luigi Atzori'], 'Disaster Management and Profile Modelling of IoT Objects: Conceptual Parameters for Interlinked Objects in Relation to Social Network Analysis': ['Asta Zelenkauskaite', 'Nik Bessis', 'Stelios Sotiriadis', 'Eleana Asimakopoulou'], 'SIoT: Giving a Social Structure to the Internet of Things': ['Luigi Atzori', 'Antonio Iera', 'Giacomo Morabito']}
# authors :  M. Pruthvi;S. Karthika;N. Bhalaji
# -------------------------------------------------------
# essayCode :  5231815
# title :  Mining Proximal Social Network Intelligence for Quality Decision Support
# ...
# authors :  Lihong Zhao
# -------------------------------------------------------
# essayCode :  8330525
# title :  An interest-driven routing algorithm in disruption-tolerant networking based social networks
# reference :  {'A survey of social-based routing in delay tolerant networks: Positive and negative social effects': ['Y. Zhu', 'B. Xu', 'X. Shi', 'Y. Wang'], 'Disruption-resilient bundle delivery mechanism in space dtns with partial segments aggregation': ['F. Jiang', 'Z. Yang', 'Y. Li'], 'Spray and wait: an efficient routing scheme for intermittently connected mobile networks': ['T. Spyropoulos', 'K. Psounis', 'C. S. Raghavendra'], 'Performance modeling of epidemic routing': ['X. Zhang', 'G. Neglia', 'J. Kurose', 'D. Towsley'], 'Advanced prophet routing in delay tolerant network': ['J. Xue', 'J. Li', 'Y. Cao', 'J. Fang'], 'Mv routing and capacity building in disruption tolerant networks': ['B. Burns', 'O. Brock', 'B. N. Levine'], 'Social network analysis for routing in disconnected delay-tolerant manets': ['E. M. Daly', 'M. Haahr'], 'How small labels create big improvements': ['P. Hui', 'J. Crowcroft'], 'Bubble rap: Social-based forwarding in delay-tolerant networks': ['P. Hui', 'J. Crowcroft', 'E. Yoneki'], 'Uncovering the overlapping community structure of complex networks in nature and society': ['G. Palla', 'I. Derenyi', 'I. Farkas', 'T. Vicsek']}
# authors :  Peng Yuan;Zhihua Yang;Yunhe Li;Qinyu Zhang
# -------------------------------------------------------
# essayCode :  5730295
# title :  Ad amīcus: Analysis of click behaviour in social relationships extracted from URLs
# reference :  {'Audience selection for on-line brand advertising: privacy-friendly social network targeting': ['Foster Provost', 'Brian Daless', 'ro', 'Rod Hook', 'Xiaohan Zhang', 'Alan Murray'], 'Network-based marketing: Identifying likely adopters via consumer networks': ['S. Hill', 'F. Provost', 'C. Volinsky'], 'Yes there is a correlation: - from social networks to personal behavior on the web': ['Parag Singla', 'Matthew Richardson'], 'Efficient influence maximization in social networks': ['Chen Wei', 'Yajun Wang', 'Siyu Yang'], 'Mining social networks for personalized email prioritization': ['S. Yoo', 'Y. Yang', 'F. Lin', 'I-C. Moon'], 'Extracting social networks and contact information from email and the web': ['A. Culotta', 'R. Bekkerman', 'A. McCallum'], 'Statistical analysis of the social network and discussion threads in slashdot': ['Vicenc Gomez', 'Andreas Kaltenbrunner', 'Vicente Lopez'], 'Quantifying Reciprocity in Social Networks': ['Huiqi Zhang', 'Ram Dantu', 'Joao Cangussu'], 'Birds of a feather: homophily in social networks': ['M. McPherson', 'L. Smith-Lovin', 'J. Cook'], 'On power-law relationships of the internet topology': ['M. Faloutsos', 'C. Faloutsos', 'P. Faloutsos'], 'Partitioning multi-edge graphs': ['Ravi Varadarajan']}
# authors :  Dhaval Makawana;BalaSundaraRaman Lakshmanan
# -------------------------------------------------------
# essayCode :  9387705
# failed
# -------------------------------------------------------
# essayCode :  5591511
# title :  Detecting Emergence in Social Networks
# reference :  {'Semi-Boolean algebra': ['J.C. Abbott'], 'The Concept of Cellular Robotics': ['G. Beni'], 'Swarm Intelligence': ['G. Beni', 'J. Want'], 'Self-organization in Social Insects': ['E. Bonabeau', 'G. Theraulaz'], 'New Paradigms and Challenges': ['P. K. Davis'], 'Operational Statistics I Basic Concepts': ['D.J. Foulis', 'C.H. R', 'all'], 'Semi-Boolean Algebras Empirical Logic and Rings Project Report': ['P. Haglich'], 'Detecting emergent behaviors with semi-Boolean algegra': ['P. Haglich', 'C. Rouff', 'L. Pullum'], 'Complexity and Self-organization': ['F. Heylighen'], 'What are emergent properties and how do they affect the engineering of complex systems?': ['C. W. Johnson'], 'Connections among quantum logics: Part 1. Quantum propositional logics': ['P.L. Lock', 'G.M. Hardegree'], 'Managing emergent behavior in distributed control systems': ['H.V.D. Parunak', 'R. V', 'erbok']}
# authors :  Peter Haglich;Christopher Rouff;Laura Pullum
# -------------------------------------------------------
# essayCode :  10047042
# title :  Classification of Cyber Hate Speech from Social Networks using Machine Learning
# reference :  {'Semantic Web - XML 2000': ['T. Berners-Lee'], 'The Semantic Web': ['T. Berners-Lee', 'J. Hendler', 'O. Lassila'], 'Standards Semantics and Survival': ['T. Berners-Lee'], 'Graph mining meets the semantic web': ['S. Lee', 'S.R. Sukumar', 'S.H. Lim'], 'Challenges in discriminating profanity from hate speech': ['Shervin Malmasi', 'Marcos Zampieri'], 'Hate speech detection with comment embeddings': ['Nemanja Djuric', 'Jing Zhou', 'Robin Morris', 'Mihajlo Grbovic', 'Vladan Radosavljevic', 'Narayan Bhamidipati'], 'Hate speech detection: A solved problem? the challenging case of long tail on twitter': ['Ziqi Zhang', 'Lei Luo'], 'Benchmarking aggression identification in social media': ['Ritesh Kumar', 'Atul Kr Ojha', 'Shervin Malmasi', 'Marcos Zampieri'], 'Detecting hate speech on twitter using a convolution-gru based deep neural network': ['Ziqi Zhang', 'David Robinson', 'Jonathan Tepper']}
# authors :  Monika Chhikara;Sanjay Kumar Malik
# -------------------------------------------------------
# essayCode :  5608773
# title :  A more comprehensive activity analysis of standard online social networking functionalities
# reference :  {'Fitcolab Experimental Online Social Networking System': ['Haris Memic'], 'Structure and Evolution of Online Social Networks': ['R. Kumar', 'J. Novak', 'A. Tomkins'], 'Measurement and Analysis of Online Social Networks': ['A. Mislove', 'M. Marcon', 'K. P. Gummadi', 'P. Druschel', 'B. Bhattacharjee'], 'Analysis of Topological Characteristics of Huge Online Social Networking Services': ['Y. Y. Ahn', 'S. Han', 'H. Kwak', 'S. Moon', 'H. Jeong'], 'Microscopic evolution of social networks': ['J. Leskovec', 'L. Backstrom', 'R. Kumar', 'A. Tomkins'], 'General Network Properties of Friendship Online Social Network': ['Haris Memic']}
# authors :  Haris Memic;Adil Joldic
# -------------------------------------------------------
# essayCode :  5231938
# title :  Groupthink and Peer Pressure: Social Influence in Online Social Network Groups
# reference :  {'Social influence networks and opinion change': ['N. Friedkin', 'E. Johnsen'], 'Group formation in large social networks: membership growth and evolution': ['L. Backstrom', 'D. Huttenlocher', 'J. Kleinberg', 'X. Lan'], 'Preferential behavior in online groups': ['L. Backstrom', 'R. Kumar', 'C. Marlow', 'J. Novak', 'A. Tomkins'], 'Influence and correlation in social networks': ['A. Anagnostopoulos', 'R. Kumar', 'M. Mahdian'], 'Measurement and analysis of online social networks': ['A. Mislove', 'M. Marcon', 'K. P. Gummadi', 'P. Druschel', 'B. Bhattacharjee'], 'Etude comparative de la distribution florale dans une portion des alpes et des jura': ['P. Jaccard'], 'Why social networks are different from other types of networks': ['M. E. J. Newman', 'J. Park'], 'A set of measures of centrality based on betweenness': ['L. C. Freeman']}
# authors :  Pan Hui;Sonja Buchegger
# -------------------------------------------------------
# essayCode :  6504138
# title :  A novel socially-aware opportunistic routing algorithm in mobile social networks
# reference :  {'QoS Multicast Routing by Using Multiple Paths/Trees in Wireless Ad Hoc Networks': ['Huayi Wu', 'Xiaohua Jia'], 'Energy efficient broadcast routing in ad hoc wireless networks': ['Deying Li', 'Xioahua Jia', 'Hai Liu'], 'Social Network Analysis for Routing in Disconnected Delay-Tolerant MANETs,': ['Daly', 'E.', 'Haahr', 'M.'], 'Impact of Social Networks on Delay Tolerant Routing,': ['Bulut', 'E.', 'Wang', 'Z.', 'Szymanski', 'B.'], 'Probabilistic routing in intermittently connected networks,': ['Lindgren', 'A.', 'Doria', 'A.', 'Schelen', 'O.'], 'Age Matters: Efficient Route Discovery in Mobile Ad Hoc Networks Using Encounter Ages,': ['Dubois-Ferriere', 'H.', 'Grossglauser', 'M.', 'Vetterli', 'M.'], 'Towards Social-aware Routing in Dynamic Communication Networks,': ['Dinh', 'T.', 'Xuan', 'Y.', 'Thai', 'M.'], 'Dynamic Social Grouping Based Routing in Mobile Ad-Hoc Network,': ['Cabaniss', 'R.', 'Madria', 'S.', 'Rush', 'G.', 'Trotta', 'A.', 'Vulli', 'S.'], 'Exploiting Friendship Relations for Efficient Routing in Mobile Social Networks,': ['Bulut', 'E.', 'Szymanski', 'B.'], 'A Social Relation Aware Routing Protocol for Mobile Ad Hoc Networks,': ['An', 'J.', 'Ko', 'Y.', 'Lee', 'D.'], 'Social Relationship Enhanced Predictable Routing in Opportunistic Network,': ['Xie', 'X.', 'Zhang', 'Y.', 'Dai', 'C.', 'Song', 'M.'], 'Predict and Spread: An Efficient Routing Algorithm for Opportunistic Networking,': ['Niu', 'J.', 'Guo', 'J.', 'Cai', 'Q.', 'Sadeh', 'N.', 'Guo', 'S.'], 'Socially-Aware Routing for Publish-Subscribe in Delay-Tolerant Mobile Ad Hoc Networks,': ['Costa', 'P.', 'Mascolo', 'C.', 'Musolesi', 'M.', 'Picco', 'G.'], 'Finding Multi-Constrained Feasible Paths By Using Depth-First Search': ['Z. Li', 'J.J. Garcia-Luna-Aceves'], 'A Routing Protocol for Socially Selfish Delay Tolerant Networks,': ['Li', 'Q.', 'Gao', 'W.', 'Zhu', 'S.', 'Cao', 'G.']}
# authors :  Gary K. W. Wong;Xiaohua Jia
# -------------------------------------------------------
# essayCode :  9693017
# title :  Traits Measuring Metrics for the Members of Semantic Social Network
# reference :  {'Modelling rules for automating the Evented Web; by semantic technologies': ['M. Coronado', 'C. Iglesias', 'E. Serrano'], 'A systematic literature review of the use of Semantic Web technologies in formal education': ['J. Jensen'], 'Towards Semantic Social Networks': ['J. J. Jung', 'J. Euzenat'], 'Semantic networks and social networks': ['S. Downes'], 'A Unified Semantic Model for Cross-Media Events Analysis in Online Social Networks': ['M. Fang', 'Y. Li', 'Y. Hu', 'S. Mao', 'P. Shi'], 'An architecture of a distributed semantic social network': ['S. Tramp', 'P. Frischmuth', 'T. Ermilov', 'S. Shekarpour', 'S. Auer'], 'Analyzing Actors and Their Discussion Topics by Semantic Social Network Analysis': ['P. A. Gloor', 'Y. Zhao'], 'Building the Semantic Web of Things Through a Dynamic Ontology': ['F. Antoniazzi', 'F. Viola'], 'Mining (Social) Network Graphs to Detect Random Link Attacks': ['N. Shrivastava', 'A. Majumder', 'R. Rastogi'], 'Metrics for Semantic Social Networks | Social Networking Service | Semantic Web': ['I Mir', 'Dr. Amjad Farooq'], 'Social Network Analysis and Churn Prediction in Telecommunications Using Graph Theory': ['S. M. Kostić', 'M. I. Simić', 'M. V. Kostić'], 'Ontology-based knowledge representation and semantic profiling in personalized semantic social networking framework': ['M. Shoaib', 'A. Basharat'], 'Meticulous analysis of Semantic Data Model-An optimal approach for ERD': ['M. I. Raza', 'Q. J. Zaib', 'M. S. Farooq', 'A. Abid', 'S. A. Khan'], 'Cognitive learning analytics using assessment data and concept map: a framework-based approach for the sustainability of programming courses': ['U. Omer', 'M. S. Farooq', 'A. Abid'], 'Earthquake prediction using expert systems: a systematic mapping study': ['R. Tehseen', 'M. S. Farooq', 'A. Abid'], 'Challenges and Issues of Resource Allocation Techniques in Cloud Computing': ['A. Abid', 'M. F. Manzoor', 'M. S. Farooq', 'U. Farooq', 'M. Hussain']}
# authors :  Rizwan Pervez Mir;Muhammad Shoaib Farooq
# -------------------------------------------------------
# essayCode :  9860751
# title :  A Novel Negative Link Prediction Algorithm for Social Networks
# reference :  {'Negative link prediction in social media': ['Tang Jiliang', 'Shiyu Chang', 'Charu Aggarwal', 'Huan Liu'], 'Predicting positive and negative links in online social networks': ['Jure Leskovec', 'Daniel Huttenlocher', 'Jon Kleinberg'], 'Negative Link Prediction and Its Applications in Online Political Networks': ['Mert Ozer', 'Mehmet Yigit Yildirim', 'Hasan Davulcu'], 'Signed network embedding in social media': ['Suhang Wang', 'Jiliang Tang', 'Charu Aggarwal', 'Yi Chang', 'Huan Liu'], 'The troll-trust model for ranking in signed networks': ['Zhaoming Wu', 'Charu C. Aggarwal', 'Jimeng Sun'], 'Mining social media with social theories: a survey': ['Jiliang Tang', 'Yi Chang', 'Huan Liu'], 'Overlapping Community Detection in Static and Dynamic Social Networks': ['Renny Márquez', 'Richard Weber'], 'A survey of signed network mining in social media': ['Jiliang Tang', 'Yi Chang', 'Charu Aggarwal', 'Huan Liu'], 'Recommendations in signed social networks': ['Jiliang Tang', 'Charu Aggarwal', 'Huan Liu'], 'Attributed signed network embedding': ['Suhang Wang', 'Charu Aggarwal', 'Jiliang Tang', 'Huan Liu'], 'Shine: Signed heterogeneous information network embedding for sentiment link prediction': ['Hongwei Wang', 'Fuzheng Zhang', 'Min Hou', 'Xing Xie', 'Minyi Guo', 'Qi Liu'], 'Efficient latent link recommendation in signed networks': ['Dongjin Song', 'David A. Meyer', 'Dacheng Tao'], 'An ensemble approach to link prediction': ['Liang Duan', 'Shuai Ma', 'Charu Aggarwal', 'Tiejun Ma', 'Jinpeng Huai'], 'Link prediction by deep non-negative matrix factorization': ['Guangfu Chen', 'Haibo Wang', 'Yili Fang', 'Ling Jiang'], 'Semantic Connotation Profile of Online Social Relationship with Interactive Language': ['Geng Lei', 'Bo Wang', 'Yuan Wang', 'Yue Zhao']}
# authors :  Debasis Das
# -------------------------------------------------------
# essayCode :  8058327
# title :  A user action based approach to determine trustworthiness among users in social network
# reference :  {'Measurement and Analysis of Online Social Networks': ['A. Mislove', 'M. Marcon', 'K. P. Gummadi', 'P. Druschel', 'B. Bhattacharjee'], 'Trust and privacy concern within social networking sites': ['Catherine Dwyer', 'Starr Roxanne Hiltz', 'Katia Passerini'], 'How to Calculate Trust between Social Network Users': ['Vedran Podobnik', 'Darko Striga', 'Ana J', 'ras', 'Ignac Lovrek'], 'A Measurement Model for Trustworthiness of Information on Social Network Services': ['Yukyong Kim', 'Eun-Wha Jhee', 'Yukyong Kim', 'Eun-Wha Jhee', 'Jong-Seok Choi', 'Yongtae Shin'], 'Action-based trust computation algorithm for Online Social Network': ['Mohit Gambhir', 'M. N Doja', 'Moinuddin'], 'Extracting reputation in multi agent system by means of social network topology': ['J. M. Pujol', 'R. Sanguesa', 'J. Delgado'], 'Spreading activation models for trust propagation': ['C.-N. Ziegler', 'G. Lausen'], 'Using probabilistic confidence models for trust inference in web-based social networks': ['U. Kuter', 'J. Golbeck'], 'Moleskiing.it: a trust-aware recommender system for ski mountaineering': ['P. Avesani', 'P. Massa', 'R. Tiella'], 'Social Network-based Trust in Prioritized Default Logic': ['Yarden Katz', 'Jennifer Golbeck'], 'Rigorous probabilistic trustinference with applications to clustering': ['T. DuBois', 'J. Golbeck', 'A. Srinivasan'], 'Exploring different types of trust propagation': ['A. Jsang', 'S. Marsh', 'S. Pope']}
# authors :  Ravi Rahangdale;Urjita Thakar
